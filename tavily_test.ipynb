# %%
pip install tavily-python
# Out:
# Collecting tavily-python
#   Downloading tavily_python-0.7.13-py3-none-any.whl.metadata (7.5 kB)
# Collecting requests (from tavily-python)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting tiktoken>=0.5.1 (from tavily-python)
#   Using cached tiktoken-0.12.0-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Collecting httpx (from tavily-python)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting regex>=2022.1.18 (from tiktoken>=0.5.1->tavily-python)
#   Using cached regex-2025.11.3-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting charset_normalizer<4,>=2 (from requests->tavily-python)
#   Using cached charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests->tavily-python)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->tavily-python)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->tavily-python)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting anyio (from httpx->tavily-python)
#   Using cached anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting httpcore==1.* (from httpx->tavily-python)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx->tavily-python)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting sniffio>=1.1 (from anyio->httpx->tavily-python)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\msi-nb\onedrive\เอกสาร\tavily\.venv\lib\site-packages (from anyio->httpx->tavily-python) (4.15.0)
# Downloading tavily_python-0.7.13-py3-none-any.whl (15 kB)
# Using cached tiktoken-0.12.0-cp311-cp311-win_amd64.whl (879 kB)
# Using cached regex-2025.11.3-cp311-cp311-win_amd64.whl (277 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl (106 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached anyio-4.11.0-py3-none-any.whl (109 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: urllib3, sniffio, regex, idna, h11, charset_normalizer, certifi, requests, httpcore, anyio, tiktoken, httpx, tavily-python
#
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ------ ---------------------------------  2/13 [regex]
#    --------- ------------------------------  3/13 [idna]
#    --------- ------------------------------  3/13 [idna]
#    ------------ ---------------------------  4/13 [h11]
#    ------------ ---------------------------  4/13 [h11]
#    --------------- ------------------------  5/13 [charset_normalizer]
#    --------------- ------------------------  5/13 [charset_normalizer]
#    --------------- ------------------------  5/13 [charset_normalizer]
#    --------------------- ------------------  7/13 [requests]
#    --------------------- ------------------  7/13 [requests]
#    ------------------------ ---------------  8/13 [httpcore]
#    ------------------------ ---------------  8/13 [httpcore]
#    ------------------------ ---------------  8/13 [httpcore]
#    ------------------------ ---------------  8/13 [httpcore]
#    ------------------------ ---------------  8/13 [httpcore]
#    --------------------------- ------------  9/13 [anyio]
#    --------------------------- ------------  9/13 [anyio]
#    --------------------------- ------------  9/13 [anyio]
#    --------------------------- ------------  9/13 [anyio]
#    --------------------------- ------------  9/13 [anyio]
#    --------------------------- ------------  9/13 [anyio]
#    ------------------------------ --------- 10/13 [tiktoken]
#    --------------------------------- ------ 11/13 [httpx]
#    --------------------------------- ------ 11/13 [httpx]
#    --------------------------------- ------ 11/13 [httpx]
#    --------------------------------- ------ 11/13 [httpx]
#    --------------------------------- ------ 11/13 [httpx]
#    --------------------------------- ------ 11/13 [httpx]
#    ------------------------------------ --- 12/13 [tavily-python]
#    ---------------------------------------- 13/13 [tavily-python]
#
# Successfully installed anyio-4.11.0 certifi-2025.11.12 charset_normalizer-3.4.4 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 regex-2025.11.3 requests-2.32.5 sniffio-1.3.1 tavily-python-0.7.13 tiktoken-0.12.0 urllib3-2.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from tavily import TavilyClient

# Load environment variables from .env file
load_dotenv()

# Get API key from environment variable
tavily_client = TavilyClient(api_key=os.getenv("TLYL-API-KEY"))
response = tavily_client.research("ข่าวน้ำท่วมวันนี้")
print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 10
#       8 # Get API key from environment variable
#       9 tavily_client = TavilyClient(api_key=os.getenv("TLYL-API-KEY"))
# ---> 10 response = tavily_client.research("ข่าวน้ำท่วมวันนี้")
#      11 print(response)
#
# AttributeError: 'TavilyClient' object has no attribute 'research'
